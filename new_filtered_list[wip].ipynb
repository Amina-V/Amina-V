# %% [markdown]
# <a href="https://colab.research.google.com/github/Amina-V/Amina-V/blob/main/new_filtered_list%5Bwip%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
nura = pd.read_csv('/content/nura_following_df.csv')
luci = pd.read_csv('/content/miss_luci_following_df.csv')
natalie = pd.read_csv('/content/princess_natalie_following_df.csv')
last = pd.read_csv('/content/Twitter Database of Creators [Stephh] - awesome_twitter_df.csv')
# Out:
#                        profileUrl       screenName  userId  \
# 0      twitter.com/amsterdamshosu   AmsterdamShosu     NaN
# 1        twitter.com/ashleylooner     AshleyLooner     NaN
# 2        twitter.com/loonerpastel     LoonerPastel     NaN
# 3        twitter.com/jchristanson     JChristanson     NaN
# 4     twitter.com/scarletwinters8  ScarletWinters8     NaN
# ...                           ...              ...     ...
# 3214        twitter.com/avnawards        avnawards     NaN
# 3215        twitter.com/skittytv_        SkittyTV_     NaN
# 3216       twitter.com/bentbox_co       bentbox_co     NaN
# 3217  twitter.com/pornhub_premium  pornhub_premium     NaN
# 3218      twitter.com/camgirlwars      CamGirlWars     NaN
#
#                                                name  \
# 0                                   SHOSU Amsterdam
# 1                                     ashley_looner
# 2                                    Ruby (Pastel)🔞
# ...

# %%
#merging all of the creator following dataframes :)
nura_luci = pd.merge(luci, nura, on='screenName', how='outer')
all = pd.merge(nura_luci, natalie, on='screenName', how='outer')

#now clean duplicates from list...
duplicates = all.duplicated(subset=['screenName'])

new_filtered_list = all[~all['profileURL'].isin(last['profileURL'])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'profileURL'
#
# The above exception was the direct cause of the following exception:
#
# ...
